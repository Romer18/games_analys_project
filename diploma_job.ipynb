# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# загрузка данных
df = pd.read_csv(r"C:\Users\romae\Downloads\archive (12)\Video_Games_Sales_as_at_22_Dec_2016.csv")

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Developer Rating
# 0          51.0         8.0       322.0  Nintendo      E
# 1           NaN         NaN         NaN       NaN    NaN
# 2          73.0         8.3       709.0  Nintendo      E
# 3          73.0         8.0       192.0  Nintendo      E
# 4           NaN         NaN         NaN       NaN    NaN

# %%
df.groupby('Platform')

# %%
# группируем продажи по платформам
group_years = df\
   .groupby(['Platform'], as_index=False)\
   .agg({'Global_Sales': 'sum'})

# %%
platform_sales = df.groupby('Platform')\
    .agg({'Global_Sales': 'sum'})\
    .sort_values(by='Global_Sales', ascending=False)

# %%
platform_sales.head()
# Out:
#           Global_Sales
# Platform
# PS2            1255.64
# X360            971.63
# PS3             939.43
# Wii             908.13
# DS              807.10

# %%
# Рисуем график общих продаж по платформам
plt.figure(figsize=(10, 6))
platform_sales.plot(kind='bar', color='skyblue')
plt.title('Общие продажи по платформам')
plt.xlabel('Платформа')
plt.ylabel('Глобальные продажи (млн)')
plt.xticks(rotation=45)
plt.show()

# %%
#группируем продажи по жанрам
genre_sales = df.groupby('Genre')\
    .agg({'Global_Sales': 'sum'})\
    .sort_values(by= 'Global_Sales', ascending=False)

# %%
#Рисуем график продаж в зависимости от жанра
plt.figure(figsize=(10, 6))
genre_sales.plot(kind='bar', color='lightgreen')
plt.title('Общие продажи по жанрам')
plt.xlabel('Жанр')
plt.ylabel('Глобальные продажи (млн)')
plt.xticks(rotation=45)
plt.show()

# %%
#группируем продажи игр по годам
early_sales = df.groupby('Year_of_Release')\
    .agg({'Global_Sales':'sum'})

# %%
#рисуем график продаж по годам
plt.figure(figsize=(12, 6))
early_sales.plot(kind='bar', color='orange') 
plt.title('Тренды продаж по годам')
plt.xlabel('Год')
plt.ylabel('Глобальные продажы(млн)')
plt.grid()
plt.show()

# %%
#находим среднее значение продаж в зависимости от региона
region_sales = df[['NA_Sales', 'EU_Sales', 'JP_Sales']].mean()

# %%
region_sales.head()
# Out:
# NA_Sales    0.263330
# EU_Sales    0.145025
# JP_Sales    0.077602
# dtype: float64

# %%
# рисуем график средних продаж по регионам
plt.figure(figsize=(8, 5))
region_sales.plot(kind='bar', color= ['blue', 'green', 'red'])
plt.title('Средние продажы по регионам')
plt.xlabel('Регион')
plt.ylabel('Средние продажы(млн)')
plt.xticks(rotation = 0)
plt.show()

# %%
# находим топ 10 игр по глобальным продажам
top_games = df.nlargest(10, 'Global_Sales')

# %%
# график топ 10 игр по глобальным продаж
plt.figure(figsize=(10, 6))
plt.barh(top_games['Name'], top_games['Global_Sales'], color= 'purple')
plt.title('Топ 10 игр по глобальным продажам')
plt.xlabel('Глобальные продажи(млн)')
#plt.gca().invert_yaxis()
plt.show()

# %%
# корреляция в зависимости от региона продаж
corelation = df[['NA_Sales', 'EU_Sales', 'JP_Sales']].corr()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(corelation, annot=True, cmap='coolwarm',
            fmt='.2f')
plt.title('Корреляция продаж между регионами')
plt.show()

# %%
# группируе глобальные продажи по годам 
sales_by_year = df.groupby('Year_of_Release')\
.agg({'Global_Sales': 'sum'})\
.reset_index()

# %%
# глобальные продажи игр по годам
plt.figure(figsize=(12, 6))
sns.lineplot(x='Year_of_Release', y='Global_Sales', data=sales_by_year, marker='o')
plt.title('Тренд глобальных продаж по годам')
plt.xlabel('Год')
plt.ylabel('Глобальные продажи (млн)')
plt.xticks(rotation=45)
plt.show()

# %%
# Функция для получения топ-N игр по годам
def top_games_per_year(df, top_n=1):
    # Сортируем по годам и продажам, а затем выбираем топ-N
    top_games = df[['Year_of_Release', 'Name', 'Global_Sales']]
    top_games = top_games.sort_values(['Year_of_Release', 'Global_Sales'], ascending=[True, False])
    top_games = top_games.groupby('Year_of_Release').head(top_n).reset_index(drop=True)
    return top_games

# Получаем топ-3 игры по годам
top_games = top_games_per_year(df)

# Удаляем строки с NaN в 'Name'
top_games = top_games.dropna(subset=['Name'])

# Визуализация
plt.figure(figsize=(15, 10))

years = top_games['Year_of_Release'].unique()

for year in years:
    games = top_games[top_games['Year_of_Release'] == year]
    plt.bar(games['Name'], games['Global_Sales'], label=year)

plt.title('Топ-3 игры по годам')
plt.xlabel('Игры')
plt.ylabel('Глобальные продажи (млн)')
plt.xticks(rotation=45)
plt.legend(title='Год')
plt.tight_layout()
plt.show()

# %%
top_games
# Out:
#     Year_of_Release                                              Name  \
# 0            1980.0                                         Asteroids
# 1            1981.0                                          Pitfall!
# 2            1982.0                                           Pac-Man
# 3            1983.0                                          Baseball
# 4            1984.0                                         Duck Hunt
# 5            1985.0                                 Super Mario Bros.
# 6            1986.0                               The Legend of Zelda
# 7            1987.0                   Zelda II: The Adventure of Link
# 8            1988.0                               Super Mario Bros. 3
# 9            1989.0                                            Tetris
# 10           1990.0                                 Super Mario World
# 11           1991.0           The Legend of Zelda: A Link to the Past
# 12           1992.0                Super Mario Land 2: 6 Golden Coins
# 13           1993.0                             Super Mario All-Stars
# 14           1994.0                               Donkey Kong Country
# 15           1995.0         Donkey Kong Country 2: Diddy's Kong Quest
# 16           1996.0                          Pokemon Red/Pokemon Blue
# 17           1997.0                                      Gran Turismo
# 18           1998.0           Pokémon Yellow: Special Pikachu Edition
# 19           1999.0                       Pokemon Gold/Pokemon Silver
# 20           2000.0                           Pokémon Crystal Version
# 21           2001.0                            Gran Turismo 3: A-Spec
# 22           2002.0                       Grand Theft Auto: Vice City
# 23           2003.0                        Need for Speed Underground
# 24           2004.0                     Grand Theft Auto: San Andreas
# 25           2005.0                                        Nintendogs
# 26           2006.0                                        Wii Sports
# 27           2007.0                                           Wii Fit
# 28           2008.0                                    Mario Kart Wii
# 29           2009.0                                 Wii Sports Resort
# 30           2010.0                                Kinect Adventures!
# 31           2011.0                    Call of Duty: Modern Warfare 3
# 32           2012.0                        Call of Duty: Black Ops II
# 33           2013.0                                Grand Theft Auto V
# 34           2014.0                                Grand Theft Auto V
# 35           2015.0                         Call of Duty: Black Ops 3
# 36           2016.0                                           FIFA 17
# 37           2017.0  Phantasy Star Online 2 Episode 4: Deluxe Package
# 38           2020.0                            Imagine: Makeup Artist
#
#     Global_Sales
# 0           4.31
# 1           4.50
# 2           7.81
# 3           3.20
# 4          28.31
# 5          40.24
# 6           6.51
# 7           4.38
# 8          17.28
# 9          30.26
# 10         20.61
# 11          4.61
# 12         11.18
# 13         10.55
# 14          9.30
# 15          5.15
# 16         31.37
# 17         10.95
# 18         14.64
# 19         23.10
# 20          6.39
# 21         14.98
# 22         16.15
# 23          7.20
# 24         20.81
# 25         24.67
# 26         82.53
# 27         22.70
# 28         35.52
# 29         32.77
# 30         21.81
# 31         14.73
# 32         13.79
# 33         21.04
# 34         12.61
# 35         14.63
# 36          7.59
# 37          0.04
# 38          0.29
